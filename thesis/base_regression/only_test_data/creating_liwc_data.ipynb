# %%
import numpy as np
import pandas as pd
import re
from scipy.stats import zscore
# Out:
# /Users/sukaraca/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Pre-processing

# %%
df = pd.read_csv("dataframes/liwc_test_prob.csv")
df.head(5)
# Out:
#    article_index        outlet  \
# 0            766  Daily Caller
# 1           1554       NYTimes
# 2           1807      HuffPost
# 3            255       FoxNews
# 4            920           CNN
#
#                                        original_text  \
# 0  Journalists were quick to take to Twitter and ...
# 1  In June, Josue, a 21-year-old Honduran, reache...
# 2  A Massachusetts county sheriff has proposed se...
# 3  We’ve got a question for all these people clai...
# 4  President Donald Trump won the White House in ...
#
#                                       processed_text  probability_0  \
# 0  journalists were quick to take to twitter and ...       0.999892
# 1  in june, josue, a 21 - year - old honduran, re...       0.000023
# 2  a massachusetts county sheriff has proposed se...       0.000039
# 3  we ’ ve got a question for all these people cl...       0.999971
# 4  president donald trump won the white house in ...       0.000028
#
#    probability_1  extremity_0  extremity_1  label  Segment  ...  Perception  \
# 0       0.000108     0.499892     0.499892      0        1  ...        7.52
# 1       0.999977     0.499977     0.499977      1        1  ...       12.89
# 2       0.999961     0.499961     0.499961      1        1  ...        8.66
# 3       0.000029     0.499971     0.499971      0        1  ...       11.14
# 4       0.999972     0.499972     0.499972      1        1  ...       11.62
#
#    motion  space  visual  auditory  feeling  time  focuspast  focuspresent  \
# 0    0.33   4.58    1.63      0.65      0.0  4.58       4.90          1.96
# 1    3.58   9.79    0.24      0.00      0.0  4.06       3.10          2.63
# 2    0.50   8.17    0.25      0.00      0.0  3.22       2.72          2.72
# 3    1.94   7.02    1.45      0.00      0.0  4.36       4.60          2.91
# 4    1.21   9.20    0.48      0.24      0.0  3.87       3.39          5.33
#
#    focusfuture
# 0         0.33
# 1         0.48
# 2         1.73
# 3         0.24
# 4         0.48
#
# [5 rows x 70 columns]

# %%
df = df.iloc[:, :9]

# %%
df.head(5)
# Out:
#    article_index        outlet  \
# 0            766  Daily Caller
# 1           1554       NYTimes
# 2           1807      HuffPost
# 3            255       FoxNews
# 4            920           CNN
#
#                                        original_text  \
# 0  Journalists were quick to take to Twitter and ...
# 1  In June, Josue, a 21-year-old Honduran, reache...
# 2  A Massachusetts county sheriff has proposed se...
# 3  We’ve got a question for all these people clai...
# 4  President Donald Trump won the White House in ...
#
#                                       processed_text  probability_0  \
# 0  journalists were quick to take to twitter and ...       0.999892
# 1  in june, josue, a 21 - year - old honduran, re...       0.000023
# 2  a massachusetts county sheriff has proposed se...       0.000039
# 3  we ’ ve got a question for all these people cl...       0.999971
# 4  president donald trump won the white house in ...       0.000028
#
#    probability_1  extremity_0  extremity_1  label
# 0       0.000108     0.499892     0.499892      0
# 1       0.999977     0.499977     0.499977      1
# 2       0.999961     0.499961     0.499961      1
# 3       0.000029     0.499971     0.499971      0
# 4       0.999972     0.499972     0.499972      1

# %%
df.rename(columns={'probability_0':'Prob_conservative',
                   'probability_1':'Prob_liberal',
                   'extremity_0':'Extremity'}, inplace=True)

# %%
df.drop(['article_index', 'extremity_1', 'Prob_conservative'], axis=1, inplace=True)

# %%
df.dtypes[df.dtypes != 'float64']
# Out:
# outlet            object
# original_text     object
# processed_text    object
# label              int64
# dtype: object

# %%
df["label"] = df["label"].astype('category')

# %%
df.to_csv('dataframes/test_prob.csv', index=False)

# %% [markdown]
# ## Post-LIWC

# %%
df = pd.read_csv("dataframes/LIWC-22 Results.csv")
df.head(5)
# Out:
#          outlet                                      original_text  \
# 0  Daily Caller  Journalists were quick to take to Twitter and ...
# 1       NYTimes  In June, Josue, a 21-year-old Honduran, reache...
# 2      HuffPost  A Massachusetts county sheriff has proposed se...
# 3       FoxNews  We’ve got a question for all these people clai...
# 4           CNN  President Donald Trump won the White House in ...
#
#                                       processed_text  Prob_liberal  Extremity  \
# 0  journalists were quick to take to twitter and ...      0.000108   0.499892
# 1  in june, josue, a 21 - year - old honduran, re...      0.999977   0.499977
# 2  a massachusetts county sheriff has proposed se...      0.999961   0.499961
# 3  we ’ ve got a question for all these people cl...      0.000029   0.499971
# 4  president donald trump won the white house in ...      0.999972   0.499972
#
#    label  Segment   WC  number  quantity  ...  Perception  motion  space  \
# 0      0        1  306    0.65      1.96  ...        7.52    0.33   4.58
# 1      1        1  419    2.86      6.44  ...       12.89    3.58   9.79
# 2      1        1  404    2.72      4.46  ...        8.66    0.50   8.17
# 3      0        1  413    1.94      4.36  ...       11.14    1.94   7.02
# 4      1        1  413    2.66      4.60  ...       11.62    1.21   9.20
#
#    visual  auditory  feeling  time  focuspast  focuspresent  focusfuture
# 0    1.63      0.65      0.0  4.58       4.90          1.96         0.33
# 1    0.24      0.00      0.0  4.06       3.10          2.63         0.48
# 2    0.25      0.00      0.0  3.22       2.72          2.72         1.73
# 3    1.45      0.00      0.0  4.36       4.60          2.91         0.24
# 4    0.48      0.24      0.0  3.87       3.39          5.33         0.48
#
# [5 rows x 54 columns]

# %%
df.drop(['Segment'], axis=1, inplace=True)

# %%
df.dtypes[df.dtypes != 'float64']
# Out:
# outlet            object
# original_text     object
# processed_text    object
# label              int64
# WC                 int64
# dtype: object

# %%
df["label"] = df["label"].astype('category')

# %% [markdown]
# ## Adding moral-emotional Dics

# %%
affect_dict_path = '../../data/dictionaries/only_affect_dict.txt'
with open(affect_dict_path, 'r') as file:
    affect_dict = file.readlines()
    # Remove newline characters
    affect_dict = [line.strip() for line in affect_dict]
    
affect_dict = [root.rstrip('*') for root in affect_dict]

# %%
moral_dict_path = '../../data/dictionaries/only_moral_dict.txt'
with open(moral_dict_path, 'r') as file:
    moral_dict = file.readlines()
    # Remove newline characters
    moral_dict = [line.strip() for line in moral_dict]
    
moral_dict = [root.rstrip('*') for root in moral_dict]

# %%
me_dict_path = '../../data/dictionaries/moral_emotional_dict.txt'
with open(me_dict_path, 'r') as file:
    me_dict = file.readlines()
    # Remove newline characters
    me_dict = [line.strip() for line in me_dict]
    
me_dict = [root.rstrip('*') for root in me_dict]

# %%
# Define the function to calculate percentages of words
def calculate_word_percentage(text, word_roots):
    text = text.lower()
    words = re.findall(r'\b\w+\b', text)
    found_words = [word for word in words if any(root in word for root in word_roots)]
    percentage = (len(found_words) / len(words)) * 100
    return percentage

# Apply the function to the DataFrame
df['UniquelyMoral'] = df['processed_text'].apply(lambda x: calculate_word_percentage(x, moral_dict))
df['UniquelyEmotional'] = df['processed_text'].apply(lambda x: calculate_word_percentage(x, affect_dict))
df['MoralEmotional'] = df['processed_text'].apply(lambda x: calculate_word_percentage(x, me_dict))

# %%
df.to_csv('dataframes/Dict_Analysis.csv', index=False)

# %%
df.head(5)
# Out:
#          outlet                                      original_text  \
# 0  Daily Caller  Journalists were quick to take to Twitter and ...
# 1       NYTimes  In June, Josue, a 21-year-old Honduran, reache...
# 2      HuffPost  A Massachusetts county sheriff has proposed se...
# 3       FoxNews  We’ve got a question for all these people clai...
# 4           CNN  President Donald Trump won the White House in ...
#
#                                       processed_text  Prob_liberal  Extremity  \
# 0  journalists were quick to take to twitter and ...      0.000108   0.499892
# 1  in june, josue, a 21 - year - old honduran, re...      0.999977   0.499977
# 2  a massachusetts county sheriff has proposed se...      0.999961   0.499961
# 3  we ’ ve got a question for all these people cl...      0.000029   0.499971
# 4  president donald trump won the white house in ...      0.999972   0.499972
#
#   label   WC  number  quantity  Drives  ...  visual  auditory  feeling  time  \
# 0     0  306    0.65      1.96    4.90  ...    1.63      0.65      0.0  4.58
# 1     1  419    2.86      6.44    3.10  ...    0.24      0.00      0.0  4.06
# 2     1  404    2.72      4.46   10.15  ...    0.25      0.00      0.0  3.22
# 3     0  413    1.94      4.36    7.02  ...    1.45      0.00      0.0  4.36
# 4     1  413    2.66      4.60    7.02  ...    0.48      0.24      0.0  3.87
#
#    focuspast  focuspresent  focusfuture  UniquelyMoral  UniquelyEmotional  \
# 0       4.90          1.96         0.33       5.882353           5.882353
# 1       3.10          2.63         0.48       5.489260           9.785203
# 2       2.72          2.72         1.73       5.693069           8.168317
# 3       4.60          2.91         0.24       4.842615          10.411622
# 4       3.39          5.33         0.48       4.358354          12.590799
#
#    MoralEmotional
# 0        1.633987
# 1        2.386635
# 2        0.990099
# 3        2.179177
# 4        0.726392
#
# [5 rows x 56 columns]

# %%
df.columns
# Out:
# Index(['outlet', 'original_text', 'processed_text', 'Prob_liberal',
#        'Extremity', 'label', 'WC', 'number', 'quantity', 'Drives',
#        'affiliation', 'achieve', 'power', 'cogproc', 'insight', 'cause',
#        'discrep', 'tentat', 'certitude', 'differ', 'emo_pos', 'emo_neg',
#        'emo_anx', 'emo_anger', 'emo_sad', 'Social', 'family', 'friend',
#        'female', 'male', 'leisure', 'home', 'work', 'money', 'relig',
#        'Physical', 'health', 'wellness', 'sexual', 'food', 'death', 'reward',
#        'risk', 'Perception', 'motion', 'space', 'visual', 'auditory',
#        'feeling', 'time', 'focuspast', 'focuspresent', 'focusfuture',
#        'UniquelyMoral', 'UniquelyEmotional', 'MoralEmotional'],
#       dtype='object')

# %%
df.drop(['outlet', 'original_text', 'processed_text', 'Prob_liberal'], axis=1, inplace=True)

# %%
df.to_csv('liwc_data.csv', index=False)

# %%
df
# Out:
#      Extremity label   WC  number  quantity  Drives  affiliation  achieve  \
# 0     0.499892     0  306    0.65      1.96    4.90         0.98     0.65
# 1     0.499977     1  419    2.86      6.44    3.10         0.95     0.24
# 2     0.499961     1  404    2.72      4.46   10.15         1.73     1.73
# 3     0.499971     0  413    1.94      4.36    7.02         3.15     1.69
# 4     0.499972     1  413    2.66      4.60    7.02         1.45     1.45
# ..         ...   ...  ...     ...       ...     ...          ...      ...
# 175   0.499933     1  437    3.43      4.81    4.81         0.92     2.97
# 176   0.495781     1  387    2.58      2.58    7.49         1.81     0.52
# 177   0.499833     1  413    5.08      8.72    3.87         1.21     0.00
# 178   0.499985     1  418    2.39      5.26   10.05         2.63     0.48
# 179   0.499963     1  408    0.49      1.96   10.05         0.98     1.47
#
#      power  cogproc  ...  visual  auditory  feeling  time  focuspast  \
# 0     3.27     7.84  ...    1.63      0.65     0.00  4.58       4.90
# 1     1.91     6.68  ...    0.24      0.00     0.00  4.06       3.10
# 2     6.93     9.16  ...    0.25      0.00     0.00  3.22       2.72
# 3     2.66     8.96  ...    1.45      0.00     0.00  4.36       4.60
# 4     4.12     8.96  ...    0.48      0.24     0.00  3.87       3.39
# ..     ...      ...  ...     ...       ...      ...   ...        ...
# 175   1.37     9.38  ...    0.23      0.00     0.23  3.66       3.43
# 176   4.91     5.17  ...    0.00      0.00     0.00  3.10       3.36
# 177   2.66     9.69  ...    0.48      0.24     0.00  3.63       8.96
# 178   6.94     4.78  ...    0.48      0.00     0.00  4.31       1.44
# 179   7.35    11.27  ...    0.98      0.25     0.00  2.70       2.70
#
#      focuspresent  focusfuture  UniquelyMoral  UniquelyEmotional  \
# 0            1.96         0.33       5.882353           5.882353
# 1            2.63         0.48       5.489260           9.785203
# 2            2.72         1.73       5.693069           8.168317
# 3            2.91         0.24       4.842615          10.411622
# 4            5.33         0.48       4.358354          12.590799
# ..            ...          ...            ...                ...
# 175          3.43         1.37       5.949657          12.128146
# 176          2.07         0.26      12.144703           7.493540
# 177          0.48         0.24       1.937046          12.348668
# 178          5.02         0.24       7.655502           9.808612
# 179          1.23         0.49       7.352941          10.049020
#
#      MoralEmotional
# 0          1.633987
# 1          2.386635
# 2          0.990099
# 3          2.179177
# 4          0.726392
# ..              ...
# 175        1.144165
# 176        4.392765
# 177        2.905569
# 178        2.153110
# 179        1.960784
#
# [180 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['Extremity', 'WC', 'number', 'quantity', 'Drives', 'affiliation',
#        'achieve', 'power', 'cogproc', 'insight', 'cause', 'discrep', 'tentat',
#        'certitude', 'differ', 'emo_pos', 'emo_neg', 'emo_anx', 'emo_anger',
#        'emo_sad', 'Social', 'family', 'friend', 'female', 'male', 'leisure',
#        'home', 'work', 'money', 'relig', 'Physical', 'health', 'wellness',
#        'sexual', 'food', 'death', 'reward', 'risk', 'Perception', 'motion',
#        'space', 'visual', 'auditory', 'feeling', 'time', 'focuspast',
#        'focuspresent', 'focusfuture', 'UniquelyMoral', 'UniquelyEmotional',
#        'MoralEmotional'],
#       dtype='object')

# %% [markdown]
# ## Z-Scores

# %%
# Out:
# Index(['outlet', 'original_text', 'processed_text', 'Prob_liberal',
#        'Extremity', 'label', 'WC', 'number', 'quantity', 'Drives',
#        'affiliation', 'achieve', 'power', 'cogproc', 'insight', 'cause',
#        'discrep', 'tentat', 'certitude', 'differ', 'emo_pos', 'emo_neg',
#        'emo_anx', 'emo_anger', 'emo_sad', 'Social', 'family', 'friend',
#        'female', 'male', 'leisure', 'home', 'work', 'money', 'relig',
#        'Physical', 'health', 'wellness', 'sexual', 'food', 'death', 'reward',
#        'risk', 'Perception', 'motion', 'space', 'visual', 'auditory',
#        'feeling', 'time', 'focuspast', 'focuspresent', 'focusfuture',
#        'UniquelyMoral', 'UniquelyEmotional', 'MoralEmotional'],
#       dtype='object')

# %%
selected_columns = df.iloc[:, 7:23]

# %%
z_scores = selected_columns.apply(zscore)

# %%
# Add the z-scores back to the DataFrame
for i, col in enumerate(selected_columns.columns):
    df[f'{col}_zscore'] = z_scores.iloc[:, i]

# %%
df.columns[:39]

# %%
columns_to_drop = ['original_text', 'processed_text' ,
                   'Probability_con', 'Probability_lib',
                   'Drives', 'Cognition','emo_pos',
                   'emo_neg', 'emo_anx', 'emo_anger', 'emo_sad',
                   'Social', 'Lifestyle', 'Physical', 'focuspast',
                   'focuspresent', 'focusfuture', 'Moral', 'Affect',
                   'Moral-Emotional',]

# %%
df_z = df.drop(columns=columns_to_drop)

# %%
df_z.to_csv('z_score_extremity.csv', index=False)

# %%
df.describe()
